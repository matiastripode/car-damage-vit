# %% [markdown]
# # Entrenamiento — DeiT-tiny vs MobileViT-small
#
# Fine-tuning de ambos modelos sobre parches del dataset CarDD. Se comparan accuracy, F1 por clase, tamaño del modelo y velocidad de inferencia.

# %% [markdown]
# ## Setup (Colab)

# %%
# !pip install -q -r requirements.txt

# %% [markdown]
# ## Configuración

# %%
# pendiente

# %% [markdown]
# ## Entrenamiento DeiT-tiny

# %%
# pendiente

# %% [markdown]
# ## Entrenamiento MobileViT-small

# %%
# pendiente

# %% [markdown]
# ## Comparación de resultados

# %%
# pendiente
